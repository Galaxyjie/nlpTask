# %%
# !python 1_layer_rnnlm_with_penn_assignment.py
# Out:
# The size of the dictionary is: 7613
# The number of the train batch is: 134
#
# Train the RNNLM……………………
# TextRNN(
#   (C): Embedding(7613, 128)
#   (W_ax): Linear(in_features=128, out_features=5, bias=False)
#   (W_aa): Linear(in_features=5, out_features=5, bias=False)
#   (tanh): Tanh()
#   (W): Linear(in_features=5, out_features=7613, bias=False)
# )
# Epoch: 0001 Batch: 50 /134 lost = 8.910127 ppl = 7406.6
# Epoch: 0001 Batch: 100 /134 lost = 8.721009 ppl = 6130.36
# Valid 4864 samples after epoch: 0001 lost = 8.564388 ppl = 5241.63
# Saving best model
# Epoch: 0002 Batch: 50 /134 lost = 8.328436 ppl = 4139.94
# Epoch: 0002 Batch: 100 /134 lost = 8.035536 ppl = 3088.79
# Valid 4864 samples after epoch: 0002 lost = 7.875298 ppl = 2631.47
# Saving best model
# Epoch: 0003 Batch: 50 /134 lost = 7.643890 ppl = 2087.85
# Epoch: 0003 Batch: 100 /134 lost = 7.430443 ppl = 1686.55
# Valid 4864 samples after epoch: 0003 lost = 7.363357 ppl = 1577.12
# Saving best model
# ...
